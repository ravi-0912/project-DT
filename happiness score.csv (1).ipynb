# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('happiness_score_DS.csv')
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
print(df.dtypes)
print(df.info())
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
# ...

# %%
df.keys()
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#Checking null values
sns.heatmap(df.isnull())

# %% [markdown]
# # Bivariate Analysis

# %%
df.drop(['Country','Region'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0               1            7.587         0.03411                   1.39651
# 1               2            7.561         0.04884                   1.30232
# 2               3            7.527         0.03328                   1.32548
# 3               4            7.522         0.03880                   1.45900
# 4               5            7.427         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
sns.lineplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)

# %%
sns.lineplot(x='Freedom',y='Happiness Score',data=df)

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df)

# %%
sns.scatterplot(x='Family',y='Happiness Rank',data=df)

# %%
df['Freedom'].plot.hist()

# %%
df['Economy (GDP per Capita)'].plot.hist()

# %% [markdown]
# # Univariate Analysis

# %%
#distribution plot
sns.distplot(df['Happiness Score'])
#data is normally distributed

# %%
sns.boxplot(df['Trust (Government Corruption)'],data=df)

# %%
sns.boxplot(df['Generosity'],data=df)

# %%
df.plot(kind='box',subplots=True,layout=(2,7))
# Out:
# Happiness Rank                      AxesSubplot(0.125,0.536818;0.0945122x0.343182)
# Happiness Score                  AxesSubplot(0.238415,0.536818;0.0945122x0.343182)
# Standard Error                   AxesSubplot(0.351829,0.536818;0.0945122x0.343182)
# Economy (GDP per Capita)         AxesSubplot(0.465244,0.536818;0.0945122x0.343182)
# Family                           AxesSubplot(0.578659,0.536818;0.0945122x0.343182)
# Health (Life Expectancy)         AxesSubplot(0.692073,0.536818;0.0945122x0.343182)
# Freedom                          AxesSubplot(0.805488,0.536818;0.0945122x0.343182)
# Trust (Government Corruption)          AxesSubplot(0.125,0.125;0.0945122x0.343182)
# Generosity                          AxesSubplot(0.238415,0.125;0.0945122x0.343182)
# Dystopia Residual                   AxesSubplot(0.351829,0.125;0.0945122x0.343182)
# dtype: object

# %%
collist=df.columns.values
ncol=10
nrows=10

# %%
plt.figure(figsize=(30,30))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['Happiness Rank', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
sns.heatmap(df.corr(),annot=True)

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %% [markdown]
# # Further analysis of the data

# %%
cols=['Happiness Rank', 'Happiness Score', 'Standard Error',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual']
df.groupby(['Happiness Score'])[cols].mean()
# Out:
#                  Happiness Rank  Happiness Score  Standard Error  \
# Happiness Score
# 2.839                       158            2.839         0.06727
# 2.905                       157            2.905         0.08658
# 3.006                       156            3.006         0.05015
# 3.340                       155            3.340         0.03656
# 3.465                       154            3.465         0.03464
# ...                         ...              ...             ...
# 7.427                         5            7.427         0.03553
# 7.522                         4            7.522         0.03880
# 7.527                         3            7.527         0.03328
# 7.561                         2            7.561         0.04884
# 7.587                         1            7.587         0.03411
#
#                  Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Happiness Score
# ...

# %%
df.groupby(['Health (Life Expectancy)'])[cols].mean()
# Out:
#                           Happiness Rank  Happiness Score  Standard Error  \
# Health (Life Expectancy)
# 0.00000                            123.0            4.507         0.07068
# 0.04776                            128.0            4.332         0.04934
# 0.06699                            148.0            3.678         0.06112
# 0.07566                            101.0            4.867         0.08742
# 0.07612                             97.0            4.898         0.09438
# ...                                  ...              ...             ...
# 0.95562                             36.0            6.329         0.03468
# 0.96538                             47.0            5.984         0.04098
# 0.99111                             46.0            5.987         0.03581
# 1.01328                             72.0            5.474         0.05051
# 1.02525                             24.0            6.798         0.03780
#
# ...

# %% [markdown]
# # Removing outliers and skewness

# %%
print("The shape before removing outliers and skewness",df.shape)
print("skewness before removing outliers")
print(df.skew())
from scipy.stats import zscore
z=np.abs(zscore(df))
df=df[(z<3).all(axis=1)]
print("new shape after removing outliers",df.shape)
print("skewness after removing outliers")
print(df.skew())
# Out:
# The shape before removing outliers and skewness (158, 10)
# skewness before removing outliers
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64
# new shape after removing outliers (149, 10)
# skewness after removing outliers
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# ...

# %%
for i in df.columns:
    if df.skew().loc[i]>0.55:
        df[i]=np.sqrt(df[i])

# %%
df.skew()
# Out:
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   0.717347
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    0.437253
# Generosity                      -0.285799
# Dystopia Residual               -0.021144
# dtype: float64

# %% [markdown]
# # Splitting the data into input and target

# %%
x=df.iloc[:,0:-1]
x.head()
# Out:
#    Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0               1            7.587        0.184689                   1.39651
# 1               2            7.561        0.220998                   1.30232
# 2               3            7.527        0.182428                   1.32548
# 3               4            7.522        0.196977                   1.45900
# 4               5            7.427        0.188494                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                       0.647904
# 1  1.40223                   0.94784  0.62877                       0.376098
# 2  1.36058                   0.87464  0.64938                       0.695392
# 3  1.33095                   0.88521  0.66973                       0.604177
# 4  1.32261                   0.90563  0.63297                       0.574082
#
#    Generosity
# 0    0.544775
# ...

# %%
y=df.iloc[:,-1]
y.head()
# Out:
# 0    2.51738
# 1    2.70201
# 2    2.49204
# 3    2.46531
# 4    2.45176
# Name: Dystopia Residual, dtype: float64

# %%
x.shape
# Out:
# (149, 9)

# %%
y.shape
# Out:
# (149,)

# %% [markdown]
# # Importing necessary libraries

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,x,y):
    max_r_score=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state= i ,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to",i,"is",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_i=i
    print("max r2 score corresponding to",final_i,"is",max_r_score)
    return final_i

# %%
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
i=maxr2_score(lreg,x,y)
# Out:
# r2 score corresponding to 42 is 0.9972294454049481
# r2 score corresponding to 43 is 0.992093210728485
# r2 score corresponding to 44 is 0.9939733555712402
# r2 score corresponding to 45 is 0.9942989444054815
# r2 score corresponding to 46 is 0.9930065452710829
# r2 score corresponding to 47 is 0.9962925184380729
# r2 score corresponding to 48 is 0.9904395692763845
# r2 score corresponding to 49 is 0.9961764907199367
# r2 score corresponding to 50 is 0.9776380794794824
# r2 score corresponding to 51 is 0.9945359863254464
# r2 score corresponding to 52 is 0.9906104771090678
# r2 score corresponding to 53 is 0.9857154783171591
# r2 score corresponding to 54 is 0.9928151570081363
# r2 score corresponding to 55 is 0.9873120282226171
# r2 score corresponding to 56 is 0.9957569415253704
# r2 score corresponding to 57 is 0.9956099246409226
# r2 score corresponding to 58 is 0.9976753526842111
# r2 score corresponding to 59 is 0.9915197323027795
# ...

# %%
print("Mean r2 score for Linear Regression:",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Linear Regression: 0.9885005376310001
# standard deviation in r2 score for Linear Regression 0.004890929628049636

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors, cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 19}

# %%
knr=KNeighborsRegressor(n_neighbors=19)
i=maxr2_score(knr,x,y)
# Out:
# r2 score corresponding to 42 is 0.33758469865847396
# r2 score corresponding to 43 is 0.2496465560901111
# r2 score corresponding to 44 is -0.13091346270221926
# r2 score corresponding to 45 is 0.31013467830162356
# r2 score corresponding to 46 is 0.2858293372857279
# r2 score corresponding to 47 is 0.24530586136470867
# r2 score corresponding to 48 is 0.223224053128663
# r2 score corresponding to 49 is -0.14837004810464327
# r2 score corresponding to 50 is -0.19923767531607983
# r2 score corresponding to 51 is 0.3432294452471887
# r2 score corresponding to 52 is -0.08276979935664719
# r2 score corresponding to 53 is 0.1949395507637125
# r2 score corresponding to 54 is 0.1328155109867195
# r2 score corresponding to 55 is 0.3172834266016594
# r2 score corresponding to 56 is 0.1810577736777481
# r2 score corresponding to 57 is 0.2822297103358141
# r2 score corresponding to 58 is 0.291160227762862
# r2 score corresponding to 59 is 0.09169163963888405
# ...

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for KNN Regression:",cross_val_score(knr,x,y,cv=10,scoring="r2").mean())
print("standard deviation in r2 score for KNN Regression",cross_val_score(knr,x,y,cv=10,scoring="r2").std())
# Out:
# Mean r2 score for KNN Regression: -0.2487487823042695
# standard deviation in r2 score for KNN Regression 0.41474383239924134

# %%
from sklearn.linear_model import Lasso
lsreg=Lasso()
parametors={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parametors,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
lsreg=Lasso(alpha=0.001)
i=maxr2_score(lsreg,x,y)
# Out:
# r2 score corresponding to 42 is 0.9955663396321641
# r2 score corresponding to 43 is 0.9921500186520978
# r2 score corresponding to 44 is 0.9869155109664882
# r2 score corresponding to 45 is 0.9925640853887163
# r2 score corresponding to 46 is 0.9909300386060389
# r2 score corresponding to 47 is 0.9937106018816535
# r2 score corresponding to 48 is 0.984946641594545
# r2 score corresponding to 49 is 0.9915680953416756
# r2 score corresponding to 50 is 0.9820452046587463
# r2 score corresponding to 51 is 0.9932552225529111
# r2 score corresponding to 52 is 0.9899787328137265
# r2 score corresponding to 53 is 0.985471779842261
# r2 score corresponding to 54 is 0.9921042750732485
# r2 score corresponding to 55 is 0.9816664817061659
# r2 score corresponding to 56 is 0.9947153351535217
# r2 score corresponding to 57 is 0.9922815023168599
# r2 score corresponding to 58 is 0.9937753992265558
# r2 score corresponding to 59 is 0.9918941000121545
# ...

# %%
print("Mean r2 score for Lasso Regression:",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Lasso Regression: 0.9885005376310001
# standard deviation in r2 score for Lasso Regression 0.004890929628049636

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet()
parametors={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(enr,parametors,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
enr=ElasticNet(alpha=0.001)
i=maxr2_score(enr,x,y)
# Out:
# r2 score corresponding to 42 is 0.9958460234497931
# r2 score corresponding to 43 is 0.9922366383907821
# r2 score corresponding to 44 is 0.9882128931661099
# r2 score corresponding to 45 is 0.992939180643449
# r2 score corresponding to 46 is 0.9912298592897715
# r2 score corresponding to 47 is 0.9940871637030657
# r2 score corresponding to 48 is 0.9858765703601925
# r2 score corresponding to 49 is 0.9921624060071716
# r2 score corresponding to 50 is 0.9819861330583596
# r2 score corresponding to 51 is 0.9933086589344167
# r2 score corresponding to 52 is 0.9901016805419595
# r2 score corresponding to 53 is 0.9855703731190041
# r2 score corresponding to 54 is 0.9923829867053183
# r2 score corresponding to 55 is 0.9825860287005134
# r2 score corresponding to 56 is 0.9949103597651244
# r2 score corresponding to 57 is 0.992799647200456
# r2 score corresponding to 58 is 0.9942561344421399
# r2 score corresponding to 59 is 0.9920139188096279
# ...

# %%
print("Mean r2 score for Elastic net Regression:",cross_val_score(enr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Elastic net Regression",cross_val_score(enr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Elastic net Regression: 0.9870947371171175
# standard deviation in r2 score for Elastic net Regression 0.0069930043120642405

# %%
from sklearn.svm import SVR

kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x,y)
    print(sv.score(x,y))
# Out:
# 0.9857425219819717
# 0.25878728713780674
# 0.27924869531063523

# %%
#we have tried the models and find Linear regression is the best till now
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=99,test_size=0.20)
lreg=LinearRegression()
lreg.fit(x,y)
y_pred=lreg.predict(x_test)

# %%
print("RMSE is:",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is:",r2_score(y_test,y_pred))
# Out:
# RMSE is: 0.04763927855540414
# r2_score is: 0.9879759113795462

# %%
import joblib
joblib.dump(lreg,'happiness_score_lreg.pkl')
# Out:
# ['happiness_score_lreg.pkl']
